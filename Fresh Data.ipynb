# %%
import pandas as pd

# %%
fresh_df = pd.read_csv('ta_scrapy/fresh_data.csv')

# %%
fresh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39054 entries, 0 to 39053
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NewName                 39054 non-null  object
#  1   NewCity                 39054 non-null  object
#  2   New Cuisine Style       39054 non-null  object
#  3   New Ranking             39054 non-null  object
#  4   New Restaurants Count   39054 non-null  object
#  5   New Ranking Normalized  39054 non-null  object
#  6   New Rating              39054 non-null  object
#  7   New Price Range         39054 non-null  object
#  8   New Number of Reviews   39054 non-null  object
#  9   URL_TA                  39054 non-null  object
# dtypes: object(10)
# memory usage: 3.0+ MB

# %%
processed_urls = set(fresh_df['URL_TA'])
50000 - len(processed_urls)
# Out:
# 10946

# %%
fresh_df['URL_TA']
# Out:
# 0        /Restaurant_Review-g187309-d6864963-Reviews-Au...
# 1        /Restaurant_Review-g189180-d12503536-Reviews-D...
# 2        /Restaurant_Review-g274924-d3199765-Reviews-Ri...
# 3        /Restaurant_Review-g189852-d7992032-Reviews-Bu...
# 4        /Restaurant_Review-g187849-d5808504-Reviews-Pi...
#                                ...
# 39548                                               URL_TA
# 39549    /Restaurant_Review-g189158-d12694064-Reviews-T...
# 39550    /Restaurant_Review-g187323-d7079377-Reviews-An...
# 39551    /Restaurant_Review-g187497-d8731146-Reviews-Al...
# 39552    /Restaurant_Review-g274856-d753385-Reviews-Bal...
# Name: URL_TA, Length: 39054, dtype: object

# %%
fresh_df.drop_duplicates(subset=['URL_TA'], inplace=True)

# %%
fresh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39054 entries, 0 to 39552
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NewName                 39054 non-null  object
#  1   NewCity                 39054 non-null  object
#  2   New Cuisine Style       39054 non-null  object
#  3   New Ranking             39054 non-null  object
#  4   New Restaurants Count   39054 non-null  object
#  5   New Ranking Normalized  39054 non-null  object
#  6   New Rating              39054 non-null  object
#  7   New Price Range         39054 non-null  object
#  8   New Number of Reviews   39054 non-null  object
#  9   URL_TA                  39054 non-null  object
# dtypes: object(10)
# memory usage: 3.3+ MB

# %%
# fresh_df.to_csv('ta_scrapy/fresh_data.csv', index=False)

# %%
fresh_df['URL_TA'].nunique()
# Out:
# 49695

# %%
# Get names of indexes for which column Age has value 3ame0
indexNames = fresh_df[fresh_df['NewName'] == 'NewName'].index
fresh_df.drop(indexNames, inplace=True)

# %%
fresh_df.dropna(inplace=True)

# %%
fresh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39053 entries, 0 to 41356
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NewName                 39053 non-null  object
#  1   NewCity                 39053 non-null  object
#  2   New Cuisine Style       39053 non-null  object
#  3   New Ranking             39053 non-null  object
#  4   New Restaurants Count   39053 non-null  object
#  5   New Ranking Normalized  39053 non-null  object
#  6   New Rating              39053 non-null  object
#  7   New Price Range         39053 non-null  object
#  8   New Number of Reviews   39053 non-null  object
#  9   URL_TA                  39053 non-null  object
# dtypes: object(10)
# memory usage: 3.3+ MB

# %%
mt_df = pd.read_csv('data/main_task.csv')

# %%
kt_df = pd.read_csv('data/kaggle_task.csv')

# %%
mt_urls = set(mt_df['URL_TA'])
len(mt_urls)
# Out:
# 39980

# %%
kt_urls = set(kt_df['URL_TA'])
len(kt_urls)
# Out:
# 10000

# %%
mt_df.nunique()
# Out:
# Restaurant_id        11909
# City                    31
# Cuisine Style         9007
# Ranking              11936
# Rating                   9
# Price Range              3
# Number of Reviews     1459
# Reviews              33516
# URL_TA               39980
# ID_TA                39980
# dtype: int64

# %%
duplicated_urls = set(mt_df.groupby('URL_TA')['URL_TA'].count().sort_values(ascending=False)[:20].index)

# %%
mt_df[mt_df['URL_TA'].apply(lambda x: x in duplicated_urls)].sort_values(by='URL_TA')
# Out:
#       Restaurant_id    City  \
# 38946       id_3242  Madrid
# 13980       id_3239  Madrid
# 11583       id_3810  Madrid
# 4732        id_3804  Madrid
# 26551       id_3240  Madrid
# 26431       id_3238  Madrid
# 10819       id_2197  Madrid
# 12628       id_2329  Madrid
# 29879       id_3662  Madrid
# 16920       id_3536  Madrid
# 26696       id_2485  Madrid
# 1579        id_2673  Madrid
# 10439        id_468  Madrid
# 25785        id_511  Madrid
# 8421        id_3811  Madrid
# 24545       id_3805  Madrid
# 25251       id_3575  Madrid
# 39847       id_3709  Madrid
# 3942        id_5646  Madrid
# 27680       id_5617  Madrid
# 147         id_4110  Madrid
# 9446        id_4104  Madrid
# 28096       id_1209  Madrid
# 4578        id_1180  Madrid
# 10183       id_1225  Madrid
# 32814       id_1197  Madrid
# 22924       id_2359  Madrid
# 36275       id_2467  Madrid
# 15525       id_3967  Madrid
# 19388       id_4331  Madrid
# 36822       id_2487  Madrid
# 5240        id_2406  Madrid
# ...
